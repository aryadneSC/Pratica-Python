# %% [markdown]
# <a href="https://colab.research.google.com/github/aryadneSC/Pratica-Python/blob/main/Introdu%C3%A7%C3%A3o_ao_Python_(Ocean_Samsung).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Problema 1:** Escreva um programa que conte quantas vezes a letra 'a' aparece em uma palavra solicitada ao usuário.

# %%
palavra = input("Digite uma palavra: ")

quantidade = palavra.count('a')

print(f"A letra 'a' aparece {quantidade} vezes")

# %% [markdown]
# **Problema 2:** Escreva um programa que percorra uma lista de palavras e exibe aquelas que possuem um comprimento maior do que um determinado valor.

# %%
palavras = ["paralelepípedo", "construtor", "sol", "mamão", "docente", "programador", "kiwi"]

comprimento_minimo = int(input("Digite o comprimento mínimo para as palavras: "))

print(f"\nPalavra com mais de {comprimento_minimo} caracteres:\n")

for palavra in palavras:
    if len(palavra) > comprimento_minimo:
        print(palavra)

# %% [markdown]
# **Problema 3:** Aprimore o exemplo anterior de modo que o usuario possa inserir a quantidade de palavras que desejar.

# %%
quantidade = int(input("Insira a quantidade de palavras: "))

palavras = []

for i in range(quantidade):
    palavra = input(f"Digite a palavra {i+1}: ")
    palavras.append(palavra)

print("\nPalavras inseridas:")
for palavra in palavras:
    print(palavra)

# %% [markdown]
# **Problema 4:** Escreva um problema que solicite ao usuário um numero inteiro positivo, e em seguida, faça uma contagem regressiva a partir desse número até zero, imprimindo cada numero no processo.

# %%
numero = int(input("Digite um número inteiro positivo: ")))

while numero >= 0:
  print(numero)
  numero = numero - 1

# %% [markdown]
# **Problema 5:** Crie um programe que gere um número inteiro aleatório entre 1 e 10.
#
# O programa deve então pedir ao usuário para adivinhar qual é esse número.
#
# Se o palpite do usuário estiver correto, o programa deve exibir uma mensagem de parabéns.
#
# Caso contrário, o programa deve informar se o número é maior ou menor que o palpite e dar ao usuário a chance de tentar novamente.
#
# O jogo segue até o usuário adivinhar corretamente o número.

# %%
import random

numero_secreto = random.randint(1, 10)

print("Bem-vindo ao jogo de adivinhação!\n")
print("Tente adivinhar um número entre 1 e 10.\n")

palpite = 0

while palpite != numero_secreto:
    try:
        palpite = int(input("\nQual é o seu palpite? "))
        if palpite < numero_secreto:
            print("O número secreto é MAIOR do que esse!")
        elif palpite > numero_secreto:
            print("O número secreto é MENOR do que esse!")
        else:
            print(f"Parabéns! Você adivinhou o número [{numero_secreto}]!")
    except ValueError:
        print("Número inválido! Por favor, digite um número inteiro e positivo...")
